# %% [markdown]
# # document count update
#
#
# - Name: **Shengqian Wang**
# - Github username: **Objqian**

# %%
import pandas as pd
#import geopandas as gpd
from matplotlib import pyplot as plt
import numpy as np
pd.options.display.max_columns = 999
#import hvplot.pandas
import folium
import nltk
import string
#import carto2gpd
#from datetime import datetime
#from datetime import date
#from sklearn.cluster import dbscan 
np.random.seed(42)
import json
import requests
import geopandas as gpd

from shapely.geometry import MultiPolygon, Polygon

from shapely import wkt

# %% [markdown]
# Import **try** - csv and  **two** shp

# %%
try10 = pd.read_csv(r'D:\OneDrive - PennO365\penn\5th\LARP 701\greenland_fin.csv')
#view try0 in a new window
#try10 = try10[4:12]
try10

two = gpd.read_file(r'D:\OneDrive - PennO365\penn\5th\LARP 701\world_final.shp')
# rebane To_Country to Country
#two = two.rename(columns={'To_Country': 'Country'})
# join the geodataframe with the cleaned up csv dataframe
#two = try10.join(two.set_index('Country'), on='Country') #我觉得也可以等到最后一起join
two
# Out:
#             To_Country  continent      area_km2           pop    lifeExp  \
# 0               Canada    America  1.003604e+07  3.553535e+07  81.953049
# 1        United States    America  9.510744e+06  3.186225e+08  78.841463
# 2              Somalia     Africa  4.843328e+05  1.351312e+07  55.467000
# 3   Russian Federation     Europe  1.701851e+07  1.438197e+08  70.743659
# 4               Norway     Europe  3.979946e+05  0.000000e+00   0.000000
# 5            Greenland  Greenland  2.206644e+06  5.629500e+04   0.000000
# 6               France     Europe  6.448479e+05  0.000000e+00   0.000000
# 7              Lebanon       Asia  1.009900e+04  5.603279e+06  79.231000
# 8                 Iraq       Asia  4.369650e+05  3.500608e+07  69.458000
# 9             Thailand       Asia  5.101256e+05  6.841677e+07  74.895000
# 10             Vietnam       Asia  3.359908e+05  9.254492e+07  75.855000
# 11               India       Asia  3.142892e+06  1.293859e+09  68.021000
# 12          Bangladesh       Asia  1.337821e+05  1.594053e+08  71.803000
# 13            Pakistan       Asia  8.741200e+05  1.855463e+08  66.139000
# 14         Afghanistan       Asia  6.522701e+05  3.275802e+07  62.895000
# 15                Iran       Asia  1.617559e+06  7.841109e+07  75.466000
# 16               Syria       Asia  1.850041e+05  1.920309e+07  69.817000
# 17              Sweden     Europe  4.505816e+05  9.696110e+06  82.253659
# 18             Belarus     Europe  2.089698e+05  9.474511e+06  72.970732
# 19             Ukraine     Europe  5.725490e+05  4.527195e+07  71.186585
# 20              Poland     Europe  3.104023e+05  3.801174e+07  77.602439
# 21             Austria     Europe  8.506490e+04  8.546356e+06  81.490244
# 22             Hungary     Europe  9.247646e+04  9.866468e+06  75.763415
# 23             Romania     Europe  2.383563e+05  1.990898e+07  74.960976
# 24           Lithuania     Europe  6.383109e+04  2.932367e+06  74.517073
# 25              Latvia     Europe  6.392353e+04  1.993782e+06  74.124390
# 26             Estonia     Europe  4.467820e+04  1.314545e+06  77.034146
# 27             Germany     Europe  3.574303e+05  8.098250e+07  81.090244
# 28            Bulgaria     Europe  1.102169e+05  7.223938e+06  74.465854
# 29              Greece     Europe  1.319646e+05  1.089241e+07  81.385366
# 30              Turkey       Asia  7.988492e+05  7.703063e+07  75.239000
POLYGON ((11.02737 58.85615, 11.46827 59.43239...
# 18  17944.209846  POLYGON ((28.17671 56.16913, 29.22951 55.91834...
# 19   8243.473515  POLYGON ((35.01266 45.73773, 35.02079 45.65122...
# 20  24347.073658  POLYGON ((23.48413 53.91250, 23.52754 53.47012...
# 21  44320.502013  POLYGON ((16.97967 48.12350, 16.90375 47.71487...
# 22  24161.425524  POLYGON ((22.08561 48.42226, 22.64082 48.15024...
# 23  19677.520253  POLYGON ((28.23355 45.48828, 28.67978 45.30403...
# 24  26258.210097  POLYGON ((26.49433 55.61511, 26.58828 55.16718...
# 25  22172.253508  POLYGON ((27.28818 57.47453, 27.77002 57.24426...
# 26  27113.685921  POLYGON ((27.98113 59.47537, 27.98112 59.47537...
# 27  43560.619244  POLYGON ((14.11969 53.75703, 14.35332 53.24817...
# 28  16302.320561  POLYGON ((22.65715 44.23492, 22.94483 43.82379...
# 29  24081.630538  MULTIPOLYGON (((22.95238 41.33799, 23.69207 41...
# 30  22401.880431  MULTIPOLYGON (((26.11704 41.82690, 27.13574 42...
# 31  57218.027926  POLYGON ((9.59423 47.52506, 9.63293 47.34760, ...
# 32  93655.334163  POLYGON ((6.04307 50.12805, 6.24275 49.90223, ...
# 33  41360.395576  POLYGON ((6.15666 50.80372, 6.04307 50.12805, ...
# 34  45668.441472  POLYGON ((6.90514 53.48216, 7.09205 53.14404, ...
# 35  26023.697849  POLYGON ((-9.03482 41.88057, -8.67195 42.13469...
# 36  31195.405242  POLYGON ((-7.45373 37.09779, -7.53711 37.42890...
# 37  48898.328662  POLYGON ((-6.19788 53.86757, -6.03299 53.15316...
# 38  10650.390178  POLYGON ((81.78796 7.52306, 81.63732 6.48178, ...
# 39  12758.647789  MULTIPOLYGON (((80.25999 42.35000, 80.18015 42...
# 40  33945.843878  MULTIPOLYGON (((8.70999 40.89998, 9.21001 41.2...
# 41  45057.074170  MULTIPOLYGON (((9.92191 54.98310, 9.28205 54.8...
# 42  38251.792480  MULTIPOLYGON (((-6.19788 53.86757, -6.95373 54...
# 43  41701.137265  POLYGON ((-14.50870 66.45589, -14.73964 65.808...
# 44   6585.895949  MULTIPOLYGON (((118.50458 9.31638, 117.17427 8...
# 45  28417.656442  POLYGON ((13.80648 46.50931, 14.63247 46.43182...
# 46  39017.537207  POLYGON ((28.59193 69.06478, 28.44594 68.36461...
# 47  27285.284674  POLYGON ((22.55814 49.08574, 22.28084 48.82539...
# 48  29119.616612  POLYGON ((15.01700 51.10667, 15.49097 50.78473...
# 49  37337.317406  MULTIPOLYGON (((132.37118 33.46364, 132.92437 ...
# 50  29786.365653  POLYGON ((32.73178 35.14003, 32.91957 35.08783...
# 51   7078.881489  POLYGON ((-2.16991 35.16840, -1.79299 34.52792...
# 52   1424.526984  POLYGON ((47.78942 8.00300, 44.96360 5.00162, ...
# 53  58585.000000  MULTIPOLYGON (((-6.71094 61.63698, -6.70991 61...
# 54   4654.395934  MULTIPOLYGON (((-16.84152 13.15139, -16.71373 ...
# 55  13010.095198  MULTIPOLYGON (((-71.71236 19.71446, -71.58730 ...
# 56  13566.538068  MULTIPOLYGON (((166.79316 -15.66881, 166.64986...
# 57  11902.682583  MULTIPOLYGON (((18.82982 45.90887, 18.82984 45...
# 58  21326.184087  MULTIPOLYGON (((128.34972 38.61224, 129.21292 ...

# %% [markdown]
# ### pivot
#
#
# tr30 = try0.pivot(index='Country', columns=['Sex','Sta'], values=['2022'])
# tr30 = tr30.reset_index()
# #tr30 = tr30[0:2]
# tr30

# %%
try0 = pd.read_csv('E:/Downloads/test1.csv')
#view try0 in a new window
try0 = try0[4:12]
try0

tr30 = try0.pivot(index='Country', columns=['Sex','Sta'], values=['2022'])
tr30 = tr30.reset_index()
#tr30 = tr30[0:2]
tr30
# Out:
#            Country         2022
# Sex                         Men                    Women
# Sta                Immigrations Emigrations Immigrations Emigrations
# 0          Denmark            0           0            0           0
# 1    Faroe Islands            1           0            0           0

# %% [markdown]
# ## Combine column name with/ with out year

# %%
# with year
#tr30.columns = [' '.join(col).strip() for col in tr30.columns.values]
# without year
tr30.columns = [' '.join(col).strip() if '2022' not in col else ' '.join(col[1:]).strip() for col in tr30.columns.values]
tr30
# Out:
#          Country  Men Immigrations  Men Emigrations  Women Immigrations  \
# 0        Denmark                 0                0                   0
# 1  Faroe Islands                 1                0                   0
#
#    Women Emigrations
# 0                  0
# 1                  0

# %%
#tr30.reset_index(inplace=True)
each = tr30.join(two.set_index('Country'), on='Country') 
each
# Out:
#          Country  Men Immigrations  Men Emigrations  Women Immigrations  \
# 0        Denmark                 0                0                   0
# 1  Faroe Islands                 1                0                   0
#
#    Women Emigrations continent      area_km2        pop  lifeExp    gdpPercap  \
# 0                  0   Denmark  42759.927703  5643475.0    80.70  45057.07417
# 1                  0   Denmark   1393.000000    54738.0    83.09  58585.00000
#
#                                             geometry
# 0  MULTIPOLYGON (((9.92191 54.98310, 9.28205 54.8...
# 1  MULTIPOLYGON (((-6.71094 61.63698, -6.70991 61...

# %%
#each.to_json()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# d:\OneDrive - PennO365\penn\5th\MUSA611\dashboard\Final project2.ipynb Cell 7 line 1
# ----> <a href='vscode-notebook-cell:/d%3A/OneDrive%20-%20PennO365/penn/5th/MUSA611/dashboard/Final%20project2.ipynb#X16sZmlsZQ%3D%3D?line=0'>1</a> two.to_json()
#
# File c:\Users\79038\anaconda3\envs\MUSA550\lib\site-packages\geopandas\geodataframe.py:749, in GeoDataFrame.to_json(self, na, show_bbox, drop_id, **kwargs)
#     696 def to_json(self, na="null", show_bbox=False, drop_id=False, **kwargs):
#     697     """
#     698     Returns a GeoJSON representation of the ``GeoDataFrame`` as a string.
#     699
#    (...)
#     747
#     748     """
# --> 749     return json.dumps(
#     750         self._to_geo(na=na, show_bbox=show_bbox, drop_id=drop_id), **kwargs
#     751     )
#
# File c:\Users\79038\anaconda3\envs\MUSA550\lib\json\__init__.py:231, in dumps(obj, skipkeys, ensure_ascii, check_circular, allow_nan, cls, indent, separators, default, sort_keys, **kw)
#     226 # cached encoder
#     227 if (not skipkeys and ensure_ascii and
#     228     check_circular and allow_nan and
#     229     cls is None and indent is None and separators is None and
#     230     default is None and not sort_keys and not kw):
# --> 231     return _default_encoder.encode(obj)
#     232 if cls is None:
#     233     cls = JSONEncoder
#
# File c:\Users\79038\anaconda3\envs\MUSA550\lib\json\encoder.py:199, in JSONEncoder.encode(self, o)
#     195         return encode_basestring(o)
#     196 # This doesn't pass the iterator directly to ''.join() because the
#     197 # exceptions aren't as detailed.  The list call should be roughly
#     198 # equivalent to the PySequence_Fast that ''.join() would do.
# --> 199 chunks = self.iterencode(o, _one_shot=True)
#     200 if not isinstance(chunks, (list, tuple)):
#     201     chunks = list(chunks)
#
# File c:\Users\79038\anaconda3\envs\MUSA550\lib\json\encoder.py:257, in JSONEncoder.iterencode(self, o, _one_shot)
#     252 else:
#     253     _iterencode = _make_iterencode(
#     254         markers, self.default, _encoder, self.indent, floatstr,
#     255         self.key_separator, self.item_separator, self.sort_keys,
#     256         self.skipkeys, _one_shot)
# --> 257 return _iterencode(o, 0)
#
# TypeError: keys must be str, int, float, bool or None, not tuple

# %% [markdown]
# ## Second Method - got a GeoDF with a children?

# %%
IM_csv = pd.read_csv(r'D:\OneDrive - PennO365\penn\5th\LARP 701\greenland_fin.csv')
#view try0 in a new window
IM_csv
# Out:
#          To_Country  MenImmigrations  MenEmigrations  WomenImmigrations  \
# 0           Denmark                0               0                  0
# 1     Faroe Islands                0               0                  0
# 2         Greenland                0               0                  0
# 3           Finland                0               0                  0
# 4           Iceland               28               4                  4
# ...             ...              ...             ...                ...
# 1765          Syria                0               0                  0
# 1766       Thailand               22               1                 28
# 1767        Vietnam                0               0                  1
# 1768     Other Asia                2               0                  1
# 1769        Oceania                1               0                  1
#
#       WomenEmigrations  Year
# 0                    0  1993
# 1                    0  1993
# 2                    0  1993
# 3                    0  1993
# 4                    2  1993
# ...                ...   ...
# 1765                 0  2022
# 1766                 2  2022
# 1767                 0  2022
# 1768                 0  2022
# 1769                 1  2022
#
# [1770 rows x 6 columns]

# %%
ct_shp = gpd.read_file(r'D:\OneDrive - PennO365\penn\5th\LARP 701\world_final.shp')
# rebane To_Country to Country
#ct_shp = ct_shp.rename(columns={'To_Country': 'Country'})
# join the geodataframe with the cleaned up csv dataframe
#ct_shpf  = ct_shp.merge(IM_csv, on='Country', how='left')
# ct_shpf = IM_csv.join(ct_shp.set_index('Country'), on='Country')
#ct_shpf2 = ct_shpf[['Country','Sex','Sta','2022','2023','geometry']]
ct_shp
# Out:
#             To_Country  continent      area_km2           pop    lifeExp  \
# 0               Canada    America  1.003604e+07  3.553535e+07  81.953049
# 1        United States    America  9.510744e+06  3.186225e+08  78.841463
# 2              Somalia     Africa  4.843328e+05  1.351312e+07  55.467000
# 3   Russian Federation     Europe  1.701851e+07  1.438197e+08  70.743659
# 4               Norway     Europe  3.979946e+05  0.000000e+00   0.000000
# 5            Greenland  Greenland  2.206644e+06  5.629500e+04   0.000000
# 6               France     Europe  6.448479e+05  0.000000e+00   0.000000
# 7              Lebanon       Asia  1.009900e+04  5.603279e+06  79.231000
# 8                 Iraq       Asia  4.369650e+05  3.500608e+07  69.458000
# 9             Thailand       Asia  5.101256e+05  6.841677e+07  74.895000
# 10             Vietnam       Asia  3.359908e+05  9.254492e+07  75.855000
# 11               India       Asia  3.142892e+06  1.293859e+09  68.021000
# 12          Bangladesh       Asia  1.337821e+05  1.594053e+08  71.803000
# 13            Pakistan       Asia  8.741200e+05  1.855463e+08  66.139000
# 14         Afghanistan       Asia  6.522701e+05  3.275802e+07  62.895000
# 15                Iran       Asia  1.617559e+06  7.841109e+07  75.466000
# 16               Syria       Asia  1.850041e+05  1.920309e+07  69.817000
# 17              Sweden     Europe  4.505816e+05  9.696110e+06  82.253659
# 18             Belarus     Europe  2.089698e+05  9.474511e+06  72.970732
# 19             Ukraine     Europe  5.725490e+05  4.527195e+07  71.186585
# 20              Poland     Europe  3.104023e+05  3.801174e+07  77.602439
# 21             Austria     Europe  8.506490e+04  8.546356e+06  81.490244
# 22             Hungary     Europe  9.247646e+04  9.866468e+06  75.763415
# 23             Romania     Europe  2.383563e+05  1.990898e+07  74.960976
# 24           Lithuania     Europe  6.383109e+04  2.932367e+06  74.517073
# 25              Latvia     Europe  6.392353e+04  1.993782e+06  74.124390
# 26             Estonia     Europe  4.467820e+04  1.314545e+06  77.034146
# 27             Germany     Europe  3.574303e+05  8.098250e+07  81.090244
# 28            Bulgaria     Europe  1.102169e+05  7.223938e+06  74.465854
# 29              Greece     Europe  1.319646e+05  1.089241e+07  81.385366
ct_shpf_long =  pd.wide_to_long(ct_shpf_l0, stubnames='val', i=['Country','Sex','Sta'], j='year')
# https://pandas.pydata.org/docs/reference/api/pandas.wide_to_long.html

# %%
ct_shpf_long
# Out:
#                                        lifeExp  \
# Country       Sex   Sta          year
# Denmark       Men   Immigrations 2022    80.70
#                                  2023    80.70
#                     Emigrations  2022    80.70
#                                  2023    80.70
#               Women Immigrations 2022    80.70
#                                  2023    80.70
#                     Emigrations  2022    80.70
#                                  2023    80.70
# Faroe Islands Men   Immigrations 2022    83.09
#                                  2023    83.09
#                     Emigrations  2022    83.09
#                                  2023    83.09
#               Women Immigrations 2022    83.09
#                                  2023    83.09
#                     Emigrations  2022    83.09
#                                  2023    83.09
#
#                                                                                 geometry  \
# Country       Sex   Sta          year
# Denmark       Men   Immigrations 2022  MULTIPOLYGON (((9.92191 54.98310, 9.28205 54.8...
#                                  2023  MULTIPOLYGON (((9.92191 54.98310, 9.28205 54.8...
#                     Emigrations  2022  MULTIPOLYGON (((9.92191 54.98310, 9.28205 54.8...
#                                  2023  MULTIPOLYGON (((9.92191 54.98310, 9.28205 54.8...
#               Women Immigrations 2022  MULTIPOLYGON (((9.92191 54.98310, 9.28205 54.8...
#                                  2023  MULTIPOLYGON (((9.92191 54.98310, 9.28205 54.8...
#                     Emigrations  2022  MULTIPOLYGON (((9.92191 54.98310, 9.28205 54.8...
#                                  2023  MULTIPOLYGON (((9.92191 54.98310, 9.28205 54.8...
# Faroe Islands Men   Immigrations 2022  MULTIPOLYGON (((-6.71094 61.63698, -6.70991 61...
#                                  2023  MULTIPOLYGON (((-6.71094 61.63698, -6.70991 61...
#                     Emigrations  2022  MULTIPOLYGON (((-6.71094 61.63698, -6.70991 61...
#                                  2023  MULTIPOLYGON (((-6.71094 61.63698, -6.70991 61...
#               Women Immigrations 2022  MULTIPOLYGON (((-6.71094 61.63698, -6.70991 61...
#                                  2023  MULTIPOLYGON (((-6.71094 61.63698, -6.70991 61...
#                     Emigrations  2022  MULTIPOLYGON (((-6.71094 61.63698, -6.70991 61...
#                                  2023  MULTIPOLYGON (((-6.71094 61.63698, -6.70991 61...
#
#                                            area_km2        pop    gdpPercap  \
# Country       Sex   Sta          year
# Denmark       Men   Immigrations 2022  42759.927703  5643475.0  45057.07417
#                                  2023  42759.927703  5643475.0  45057.07417
#                     Emigrations  2022  42759.927703  5643475.0  45057.07417
#                                  2023  42759.927703  5643475.0  45057.07417
#               Women Immigrations 2022  42759.927703  5643475.0  45057.07417
#                                  2023  42759.927703  5643475.0  45057.07417
#                     Emigrations  2022  42759.927703  5643475.0  45057.07417
#                                  2023  42759.927703  5643475.0  45057.07417
# Faroe Islands Men   Immigrations 2022   1393.000000    54738.0  58585.00000
#                                  2023   1393.000000    54738.0  58585.00000
#                     Emigrations  2022   1393.000000    54738.0  58585.00000
#                                  2023   1393.000000    54738.0  58585.00000
#               Women Immigrations 2022   1393.000000    54738.0  58585.00000
#                                  2023   1393.000000    54738.0  58585.00000
#                     Emigrations  2022   1393.000000    54738.0  58585.00000
#                                  2023   1393.000000    54738.0  58585.00000
#
#                                       continent  val
# Country       Sex   Sta          year
# Denmark       Men   Immigrations 2022   Denmark    0
#                                  2023   Denmark    3
#                     Emigrations  2022   Denmark    0
#                                  2023   Denmark    3
#               Women Immigrations 2022   Denmark    0
#                                  2023   Denmark    3
#                     Emigrations  2022   Denmark    0
#                                  2023   Denmark    3
# Faroe Islands Men   Immigrations 2022   Denmark    1
#                                  2023   Denmark    4
#                     Emigrations  2022   Denmark    0
#                                  2023   Denmark    3
#               Women Immigrations 2022   Denmark    0
#                                  2023   Denmark    3
#                     Emigrations  2022   Denmark    0
#                                  2023   Denmark    3

# %%
ct_shpf_longsb = ct_shpf_long
ct_shpf_longsb.reset_index(inplace=True)
#ct_shpf_longsb[['level_0','index']]
ct_shpf_longsb
# Out:
#           Country    Sex           Sta  year  lifeExp  \
# 0         Denmark    Men  Immigrations  2022    80.70
# 1         Denmark    Men  Immigrations  2023    80.70
# 2         Denmark    Men   Emigrations  2022    80.70
# 3         Denmark    Men   Emigrations  2023    80.70
# 4         Denmark  Women  Immigrations  2022    80.70
# 5         Denmark  Women  Immigrations  2023    80.70
# 6         Denmark  Women   Emigrations  2022    80.70
# 7         Denmark  Women   Emigrations  2023    80.70
# 8   Faroe Islands    Men  Immigrations  2022    83.09
# 9   Faroe Islands    Men  Immigrations  2023    83.09
# 10  Faroe Islands    Men   Emigrations  2022    83.09
# 11  Faroe Islands    Men   Emigrations  2023    83.09
# 12  Faroe Islands  Women  Immigrations  2022    83.09
# 13  Faroe Islands  Women  Immigrations  2023    83.09
# 14  Faroe Islands  Women   Emigrations  2022    83.09
# 15  Faroe Islands  Women   Emigrations  2023    83.09
#
#                                              geometry      area_km2  \
# 0   MULTIPOLYGON (((9.92191 54.98310, 9.28205 54.8...  42759.927703
# 1   MULTIPOLYGON (((9.92191 54.98310, 9.28205 54.8...  42759.927703
# 2   MULTIPOLYGON (((9.92191 54.98310, 9.28205 54.8...  42759.927703
# 3   MULTIPOLYGON (((9.92191 54.98310, 9.28205 54.8...  42759.927703
# 4   MULTIPOLYGON (((9.92191 54.98310, 9.28205 54.8...  42759.927703
# 5   MULTIPOLYGON (((9.92191 54.98310, 9.28205 54.8...  42759.927703
# 6   MULTIPOLYGON (((9.92191 54.98310, 9.28205 54.8...  42759.927703
# 7   MULTIPOLYGON (((9.92191 54.98310, 9.28205 54.8...  42759.927703
# 8   MULTIPOLYGON (((-6.71094 61.63698, -6.70991 61...   1393.000000
# 9   MULTIPOLYGON (((-6.71094 61.63698, -6.70991 61...   1393.000000
# 10  MULTIPOLYGON (((-6.71094 61.63698, -6.70991 61...   1393.000000
# 11  MULTIPOLYGON (((-6.71094 61.63698, -6.70991 61...   1393.000000
# 12  MULTIPOLYGON (((-6.71094 61.63698, -6.70991 61...   1393.000000
# 13  MULTIPOLYGON (((-6.71094 61.63698, -6.70991 61...   1393.000000
# 14  MULTIPOLYGON (((-6.71094 61.63698, -6.70991 61...   1393.000000
# 15  MULTIPOLYGON (((-6.71094 61.63698, -6.70991 61...   1393.000000
#
#           pop    gdpPercap continent  val
# 0   5643475.0  45057.07417   Denmark    0
# 1   5643475.0  45057.07417   Denmark    3
# 2   5643475.0  45057.07417   Denmark    0
# 3   5643475.0  45057.07417   Denmark    3
# 4   5643475.0  45057.07417   Denmark    0
# 5   5643475.0  45057.07417   Denmark    3
# 6   5643475.0  45057.07417   Denmark    0
# 7   5643475.0  45057.07417   Denmark    3
# 8     54738.0  58585.00000   Denmark    1
# 9     54738.0  58585.00000   Denmark    4
# 10    54738.0  58585.00000   Denmark    0
# 11    54738.0  58585.00000   Denmark    3
# 12    54738.0  58585.00000   Denmark    0
# 13    54738.0  58585.00000   Denmark    3
# 14    54738.0  58585.00000   Denmark    0
# 15    54738.0  58585.00000   Denmark    3

# %%
ct_shpf_df = pd.DataFrame(ct_shpf_longsb)
ct_shpf_df.drop("geometry",axis=1)
ct_shpf_geo = ct_shp[['Country','geometry']]

# %%
IM_csv
# Out:
#          To_Country  MenImmigrations  MenEmigrations  WomenImmigrations  \
# 0           Denmark                0               0                  0
# 1     Faroe Islands                0               0                  0
# 2         Greenland                0               0                  0
# 3           Finland                0               0                  0
# 4           Iceland               28               4                  4
# ...             ...              ...             ...                ...
# 1765          Syria                0               0                  0
# 1766       Thailand               22               1                 28
# 1767        Vietnam                0               0                  1
# 1768     Other Asia                2               0                  1
# 1769        Oceania                1               0                  1
#
#       WomenEmigrations  Year
# 0                    0  1993
# 1                    0  1993
# 2                    0  1993
# 3                    0  1993
# 4                    2  1993
# ...                ...   ...
# 1765                 0  2022
# 1766                 2  2022
# 1767                 0  2022
# 1768                 0  2022
# 1769                 1  2022
#
# [1770 rows x 6 columns]

# %%
j = (ct_shpf_df.groupby(['Country','continent','area_km2','pop','lifeExp','gdpPercap'])
       .apply(lambda x: x[['Sex','Sta','year','val']].to_dict('records'))
       .reset_index()
       .rename(columns={0:'data'})
#       .to_json(orient='records')
 )

# https://stackoverflow.com/questions/40470954/convert-pandas-dataframe-to-nested-json

# %%
j = (IM_csv.groupby(['To_Country'])
       .apply(lambda x: x.groupby('Year').apply(lambda y: y[['MenImmigrations','MenEmigrations','WomenImmigrations','WomenEmigrations']].to_dict('records')).to_dict())
       .reset_index()
       .rename(columns={0:'migdata'})
#       .to_json(orient='records')
)

# %%
j.to_clipboard()

# %%
ct_shpf_geof  = ct_shp.merge(j, on='To_Country', how='left')

# %%
ct_shpf_geof
# Out:
#             To_Country  continent      area_km2           pop    lifeExp  \
# 0               Canada    America  1.003604e+07  3.553535e+07  81.953049
# 1        United States    America  9.510744e+06  3.186225e+08  78.841463
# 2              Somalia     Africa  4.843328e+05  1.351312e+07  55.467000
# 3   Russian Federation     Europe  1.701851e+07  1.438197e+08  70.743659
# 4               Norway     Europe  3.979946e+05  0.000000e+00   0.000000
# 5            Greenland  Greenland  2.206644e+06  5.629500e+04   0.000000
# 6               France     Europe  6.448479e+05  0.000000e+00   0.000000
# 7              Lebanon       Asia  1.009900e+04  5.603279e+06  79.231000
# 8                 Iraq       Asia  4.369650e+05  3.500608e+07  69.458000
# 9             Thailand       Asia  5.101256e+05  6.841677e+07  74.895000
# 10             Vietnam       Asia  3.359908e+05  9.254492e+07  75.855000
# 11               India       Asia  3.142892e+06  1.293859e+09  68.021000
# 12          Bangladesh       Asia  1.337821e+05  1.594053e+08  71.803000
# 13            Pakistan       Asia  8.741200e+05  1.855463e+08  66.139000
# 14         Afghanistan       Asia  6.522701e+05  3.275802e+07  62.895000
# 15                Iran       Asia  1.617559e+06  7.841109e+07  75.466000
# 16               Syria       Asia  1.850041e+05  1.920309e+07  69.817000
# 17              Sweden     Europe  4.505816e+05  9.696110e+06  82.253659
# 18             Belarus     Europe  2.089698e+05  9.474511e+06  72.970732
# 19             Ukraine     Europe  5.725490e+05  4.527195e+07  71.186585
# 20              Poland     Europe  3.104023e+05  3.801174e+07  77.602439
# 21             Austria     Europe  8.506490e+04  8.546356e+06  81.490244
# 22             Hungary     Europe  9.247646e+04  9.866468e+06  75.763415
# 23             Romania     Europe  2.383563e+05  1.990898e+07  74.960976
# 24           Lithuania     Europe  6.383109e+04  2.932367e+06  74.517073
# 25              Latvia     Europe  6.392353e+04  1.993782e+06  74.124390
# 26             Estonia     Europe  4.467820e+04  1.314545e+06  77.034146
# 27             Germany     Europe  3.574303e+05  8.098250e+07  81.090244
# 28            Bulgaria     Europe  1.102169e+05  7.223938e+06  74.465854
# 29              Greece     Europe  1.319646e+05  1.089241e+07  81.385366
# 30              Turkey       Asia  7.988492e+05  7.703063e+07  75.239000
# 31         Switzerland     Europe  4.618525e+04  8.188649e+06  83.197561
# 32          Luxembourg     Europe  2.416870e+03  5.563190e+05  82.229268
# 33             Belgium     Europe  3.012604e+04  1.120906e+07  81.287805
# 34         Netherlands     Europe  4.002410e+04  1.686501e+07  81.707317
# 35            Portugal     Europe  9.340859e+04  1.040106e+07  81.121951
# 36               Spain     Europe  5.023065e+05  4.648088e+07  83.229268
# 37             Ireland     Europe  5.845751e+04  4.657740e+06  81.348780
# 38           Sri Lanka       Asia  6.537039e+04  2.077100e+07  74.906000
# 39               China       Asia  9.409830e+06  1.364270e+09  75.932000
# 40               Italy     Europe  3.151049e+05  6.078914e+07  83.090244
# 25  22172.253508  POLYGON ((27.28818 57.47453, 27.77002 57.24426...
# 26  27113.685921  POLYGON ((27.98113 59.47537, 27.98112 59.47537...
# 27  43560.619244  POLYGON ((14.11969 53.75703, 14.35332 53.24817...
# 28  16302.320561  POLYGON ((22.65715 44.23492, 22.94483 43.82379...
# 29  24081.630538  MULTIPOLYGON (((22.95238 41.33799, 23.69207 41...
# 30  22401.880431  MULTIPOLYGON (((26.11704 41.82690, 27.13574 42...
# 31  57218.027926  POLYGON ((9.59423 47.52506, 9.63293 47.34760, ...
# 32  93655.334163  POLYGON ((6.04307 50.12805, 6.24275 49.90223, ...
# 33  41360.395576  POLYGON ((6.15666 50.80372, 6.04307 50.12805, ...
# 34  45668.441472  POLYGON ((6.90514 53.48216, 7.09205 53.14404, ...
# 35  26023.697849  POLYGON ((-9.03482 41.88057, -8.67195 42.13469...
# 36  31195.405242  POLYGON ((-7.45373 37.09779, -7.53711 37.42890...
# 37  48898.328662  POLYGON ((-6.19788 53.86757, -6.03299 53.15316...
# 38  10650.390178  POLYGON ((81.78796 7.52306, 81.63732 6.48178, ...
# 39  12758.647789  MULTIPOLYGON (((80.25999 42.35000, 80.18015 42...
# 40  33945.843878  MULTIPOLYGON (((8.70999 40.89998, 9.21001 41.2...
# 41  45057.074170  MULTIPOLYGON (((9.92191 54.98310, 9.28205 54.8...
# 42  38251.792480  MULTIPOLYGON (((-6.19788 53.86757, -6.95373 54...
# 43  41701.137265  POLYGON ((-14.50870 66.45589, -14.73964 65.808...
# 44   6585.895949  MULTIPOLYGON (((118.50458 9.31638, 117.17427 8...
# 45  28417.656442  POLYGON ((13.80648 46.50931, 14.63247 46.43182...
# 46  39017.537207  POLYGON ((28.59193 69.06478, 28.44594 68.36461...
# 47  27285.284674  POLYGON ((22.55814 49.08574, 22.28084 48.82539...
# 48  29119.616612  POLYGON ((15.01700 51.10667, 15.49097 50.78473...
# 49  37337.317406  MULTIPOLYGON (((132.37118 33.46364, 132.92437 ...
# 50  29786.365653  POLYGON ((32.73178 35.14003, 32.91957 35.08783...
# 51   7078.881489  POLYGON ((-2.16991 35.16840, -1.79299 34.52792...
# 52   1424.526984  POLYGON ((47.78942 8.00300, 44.96360 5.00162, ...
# 53  58585.000000  MULTIPOLYGON (((-6.71094 61.63698, -6.70991 61...
# 54   4654.395934  MULTIPOLYGON (((-16.84152 13.15139, -16.71373 ...
# 55  13010.095198  MULTIPOLYGON (((-71.71236 19.71446, -71.58730 ...
# 56  13566.538068  MULTIPOLYGON (((166.79316 -15.66881, 166.64986...
# 57  11902.682583  MULTIPOLYGON (((18.82982 45.90887, 18.82984 45...
# 58  21326.184087  MULTIPOLYGON (((128.34972 38.61224, 129.21292 ...
#
#                                               migdata
# 0   {1993: [{'MenImmigrations': 4, 'MenEmigrations...
# 1   {1993: [{'MenImmigrations': 1, 'MenEmigrations...
# 2   {1993: [{'MenImmigrations': 0, 'MenEmigrations...
# 3   {1993: [{'MenImmigrations': 0, 'MenEmigrations...
# 4   {1993: [{'MenImmigrations': 15, 'MenEmigration...
# 5   {1993: [{'MenImmigrations': 0, 'MenEmigrations...
# 6   {1993: [{'MenImmigrations': 0, 'MenEmigrations...
# 7   {1993: [{'MenImmigrations': 1, 'MenEmigrations...
# 8   {1993: [{'MenImmigrations': 0, 'MenEmigrations...
# 9   {1993: [{'MenImmigrations': 1, 'MenEmigrations...
# 10  {1993: [{'MenImmigrations': 0, 'MenEmigrations...
# 11  {1993: [{'MenImmigrations': 0, 'MenEmigrations...
# 12  {1993: [{'MenImmigrations': 0, 'MenEmigrations...
# 13  {1993: [{'MenImmigrations': 0, 'MenEmigrations...
# 14  {1993: [{'MenImmigrations': 0, 'MenEmigrations...
# 15  {1993: [{'MenImmigrations': 0, 'MenEmigrations...
# 16  {1993: [{'MenImmigrations': 0, 'MenEmigrations...
# 17  {1993: [{'MenImmigrations': 3, 'MenEmigrations...
# 18  {1993: [{'MenImmigrations': 0, 'MenEmigrations...
# 19  {1993: [{'MenImmigrations': 1, 'MenEmigrations...
# 20  {1993: [{'MenImmigrations': 0, 'MenEmigrations...
# 21  {1993: [{'MenImmigrations': 0, 'MenEmigrations...
# 22  {1993: [{'MenImmigrations': 0, 'MenEmigrations...
# 23  {1993: [{'MenImmigrations': 0, 'MenEmigrations...
# 24  {1993: [{'MenImmigrations': 0, 'MenEmigrations...
# 25  {1993: [{'MenImmigrations': 0, 'MenEmigrations...
# 26  {1993: [{'MenImmigrations': 0, 'MenEmigrations...
# 27  {1993: [{'MenImmigrations': 1, 'MenEmigrations...
# 28  {1993: [{'MenImmigrations': 0, 'MenEmigrations...
# 29  {1993: [{'MenImmigrations': 0, 'MenEmigrations...
# 30  {1993: [{'MenImmigrations': 0, 'MenEmigrations...
# 31  {1993: [{'MenImmigrations': 0, 'MenEmigrations...
# 32  {1993: [{'MenImmigrations': 0, 'MenEmigrations...
# 33  {1993: [{'MenImmigrations': 0, 'MenEmigrations...
# 34  {1993: [{'MenImmigrations': 1, 'MenEmigrations...
# 35  {1993: [{'MenImmigrations': 0, 'MenEmigrations...
# 36  {1993: [{'MenImmigrations': 0, 'MenEmigrations...
# 37  {1993: [{'MenImmigrations': 1, 'MenEmigrations...
# 38  {1993: [{'MenImmigrations': 0, 'MenEmigrations...
# 39  {1993: [{'MenImmigrations': 1, 'MenEmigrations...
# 40  {1993: [{'MenImmigrations': 1, 'MenEmigrations...
# 41  {1993: [{'MenImmigrations': 0, 'MenEmigrations...
# 42  {1993: [{'MenImmigrations': 4, 'MenEmigrations...
# 43  {1993: [{'MenImmigrations': 28, 'MenEmigration...
# 44  {1993: [{'MenImmigrations': 0, 'MenEmigrations...
# 45  {1993: [{'MenImmigrations': 0, 'MenEmigrations...
# 46  {1993: [{'MenImmigrations': 0, 'MenEmigrations...
# 47  {1993: [{'MenImmigrations': 0, 'MenEmigrations...
# 48  {1993: [{'MenImmigrations': 0, 'MenEmigrations...
# 49  {1993: [{'MenImmigrations': 0, 'MenEmigrations...
# 50  {1993: [{'MenImmigrations': 0, 'MenEmigrations...
# 51  {1993: [{'MenImmigrations': 0, 'MenEmigrations...
# 52  {1993: [{'MenImmigrations': 0, 'MenEmigrations...
# 53  {1993: [{'MenImmigrations': 0, 'MenEmigrations...
# 54  {1993: [{'MenImmigrations': 0, 'MenEmigrations...
# 55  {1993: [{'MenImmigrations': 3, 'MenEmigrations...
# 56  {1993: [{'MenImmigrations': 3, 'MenEmigrations...
# 57  {1993: [{'MenImmigrations': 0, 'MenEmigrations...
# 58  {1993: [{'MenImmigrations': 0, 'MenEmigrations...

# %%
#ct_shpf_geof.to_file('dataframe2.geojson', driver='GeoJSON') ValueError: Invalid field type <class 'list'>
#https://stackoverflow.com/questions/70777743/convert-geopandas-geodataframe-to-geojson
with open('dataframe_testfinal.geojson' , 'w') as file:
    file.write(ct_shpf_geof.to_json())

# %% [markdown]
# this is a ref from R, but did not get time to test if that worked for SF....

# %%
STOP!
# Out:
#   Cell In[47], line 1
#     STOP!
#         ^
# SyntaxError: invalid syntax

# %% [markdown]
# If create wide to long, try this's code

# %% [markdown]
# # ERROR

# %%
df['geometry'] = df['geometry'].apply(wkt.loads)

# Now convert the pandas DataFrame to a GeoDataFrame
gdf = gpd.GeoDataFrame(df, geometry='geometry')

# Set the coordinate reference system (CRS) if known
gdf.set_crs(epsg=4326, inplace=True)

# %%
# geojson
def create_nested_structure(row):
    properties = row.drop('geometry').to_dict()  # Convert non-geometry columns to a dictionary
    properties['children'] = {'Sex': properties.pop('Sex'), 'Sta': properties.pop('Sta'),'Year': properties.pop('yer')}
    feature = {'type': 'Feature',
               'properties': properties,
               'geometry': json.loads(row['geometry'].to_json())}  # Convert geometry to GeoJSON
    return feature

# Apply the function to each row to create a list of GeoJSON features
features = ct_shpf_long.apply(create_nested_structure, axis=1).tolist()

# Create the final GeoJSON structure
geojson_structure = {'type': 'FeatureCollection', 'features': features}

# Convert the GeoJSON structure to a string
geojson_str = json.dumps(geojson_structure, indent=4)

# Save to a GeoJSON file
output_filename = 'output0.geojson'
with open(output_filename, 'w') as file:
    file.write(geojson_str)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# d:\OneDrive - PennO365\penn\5th\MUSA611\dashboard\Final project2.ipynb Cell 26 line 1
#       <a href='vscode-notebook-cell:/d%3A/OneDrive%20-%20PennO365/penn/5th/MUSA611/dashboard/Final%20project2.ipynb#X44sZmlsZQ%3D%3D?line=7'>8</a>     return feature
#      <a href='vscode-notebook-cell:/d%3A/OneDrive%20-%20PennO365/penn/5th/MUSA611/dashboard/Final%20project2.ipynb#X44sZmlsZQ%3D%3D?line=9'>10</a> # Apply the function to each row to create a list of GeoJSON features
# ---> <a href='vscode-notebook-cell:/d%3A/OneDrive%20-%20PennO365/penn/5th/MUSA611/dashboard/Final%20project2.ipynb#X44sZmlsZQ%3D%3D?line=10'>11</a> features = cospf_long.apply(create_nested_structure, axis=1).tolist()
#      <a href='vscode-notebook-cell:/d%3A/OneDrive%20-%20PennO365/penn/5th/MUSA611/dashboard/Final%20project2.ipynb#X44sZmlsZQ%3D%3D?line=12'>13</a> # Create the final GeoJSON structure
#      <a href='vscode-notebook-cell:/d%3A/OneDrive%20-%20PennO365/penn/5th/MUSA611/dashboard/Final%20project2.ipynb#X44sZmlsZQ%3D%3D?line=13'>14</a> geojson_structure = {'type': 'FeatureCollection', 'features': features}
#
# File c:\Users\79038\anaconda3\envs\MUSA550\lib\site-packages\geopandas\geodataframe.py:1390, in GeoDataFrame.apply(self, func, axis, raw, result_type, args, **kwargs)
#    1388 @doc(pd.DataFrame)
#    1389 def apply(self, func, axis=0, raw=False, result_type=None, args=(), **kwargs):
# -> 1390     result = super().apply(
#    1391         func, axis=axis, raw=raw, result_type=result_type, args=args, **kwargs
#    1392     )
#    1393     if (
#    1394         isinstance(result, GeoDataFrame)
#    1395         and self._geometry_column_name in result.columns
#    1396         and isinstance(result[self._geometry_column_name].dtype, GeometryDtype)
#    1397     ):
#    1398         # apply calls _constructor which resets geom col name to geometry
#    1399         result._geometry_column_name = self._geometry_column_name
#
# File c:\Users\79038\anaconda3\envs\MUSA550\lib\site-packages\pandas\core\frame.py:8845, in DataFrame.apply(self, func, axis, raw, result_type, args, **kwargs)
#    8834 from pandas.core.apply import frame_apply
#    8836 op = frame_apply(
#    8837     self,
#    8838     func=func,
#    (...)
#    8843     kwargs=kwargs,
#    8844 )
# -> 8845 return op.apply().__finalize__(self, method="apply")
#
# File c:\Users\79038\anaconda3\envs\MUSA550\lib\site-packages\pandas\core\apply.py:733, in FrameApply.apply(self)
#     730 elif self.raw:
#     731     return self.apply_raw()
# --> 733 return self.apply_standard()
#
# File c:\Users\79038\anaconda3\envs\MUSA550\lib\site-packages\pandas\core\apply.py:857, in FrameApply.apply_standard(self)
#     856 def apply_standard(self):
# --> 857     results, res_index = self.apply_series_generator()
#     859     # wrap results
#     860     return self.wrap_results(results, res_index)
#
# File c:\Users\79038\anaconda3\envs\MUSA550\lib\site-packages\pandas\core\apply.py:873, in FrameApply.apply_series_generator(self)
#     870 with option_context("mode.chained_assignment", None):
#     871     for i, v in enumerate(series_gen):
#     872         # ignore SettingWithCopy here in case the user mutates
# --> 873         results[i] = self.f(v)
#     874         if isinstance(results[i], ABCSeries):
#     875             # If we have a view on v, we need to make a copy because
#     876             #  series_generator will swap out the underlying data
#     877             results[i] = results[i].copy(deep=False)
#
# d:\OneDrive - PennO365\penn\5th\MUSA611\dashboard\Final project2.ipynb Cell 26 line 4
#       <a href='vscode-notebook-cell:/d%3A/OneDrive%20-%20PennO365/penn/5th/MUSA611/dashboard/Final%20project2.ipynb#X44sZmlsZQ%3D%3D?line=1'>2</a> def create_nested_structure(row):
#       <a href='vscode-notebook-cell:/d%3A/OneDrive%20-%20PennO365/penn/5th/MUSA611/dashboard/Final%20project2.ipynb#X44sZmlsZQ%3D%3D?line=2'>3</a>     properties = row.drop('geometry').to_dict()  # Convert non-geometry columns to a dictionary
# ----> <a href='vscode-notebook-cell:/d%3A/OneDrive%20-%20PennO365/penn/5th/MUSA611/dashboard/Final%20project2.ipynb#X44sZmlsZQ%3D%3D?line=3'>4</a>     properties['children'] = {'Sex': properties.pop('Sex'), 'Sta': properties.pop('Sta'),'Year': properties.pop('yer')}
#       <a href='vscode-notebook-cell:/d%3A/OneDrive%20-%20PennO365/penn/5th/MUSA611/dashboard/Final%20project2.ipynb#X44sZmlsZQ%3D%3D?line=4'>5</a>     feature = {'type': 'Feature',
#       <a href='vscode-notebook-cell:/d%3A/OneDrive%20-%20PennO365/penn/5th/MUSA611/dashboard/Final%20project2.ipynb#X44sZmlsZQ%3D%3D?line=5'>6</a>                'properties': properties,
#       <a href='vscode-notebook-cell:/d%3A/OneDrive%20-%20PennO365/penn/5th/MUSA611/dashboard/Final%20project2.ipynb#X44sZmlsZQ%3D%3D?line=6'>7</a>                'geometry': json.loads(row['geometry'].to_json())}  # Convert geometry to GeoJSON
#       <a href='vscode-notebook-cell:/d%3A/OneDrive%20-%20PennO365/penn/5th/MUSA611/dashboard/Final%20project2.ipynb#X44sZmlsZQ%3D%3D?line=7'>8</a>     return feature
#
# KeyError: 'Sex'

# %%
ct_shpf.to_file('dataframe.geojson', driver='GeoJSON')
# Out:
# c:\Users\79038\anaconda3\envs\MUSA550\lib\site-packages\geopandas\io\file.py:362: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   pd.Int64Index,

# %%
import networkx as nx

# %%
g = nx.from_pandas_edgelist(ct_shpf, 'parent_id', 'child_id', create_using=nx.DiGraph())

df1 = df.rename(lambda x: '_'.join(x.split('_')[::-1]), axis=1)
df1 = pd.wide_to_long(df1.reset_index(), stubnames=['id', 'name'],
                i='index', j='type', suffix='\w+', sep='_')
d = {v: {'level': l, 'name': n} for v,l,n in zip(df1.id, df1.level, df1.name)}
root_id = df.loc[0, 'parent_id']
d[root_id]['level'] = 0

nx.set_node_attributes(g, d)
out = [tree_data_custom(g, root_id)]

# %%
data = {
    'tam': ['A', 'A', 'B', 'B', 'C', 'C'],
    'dram': ['cor', 'dis', 'cor', 'dis', 'cor', 'dis'],
    'green': ['yes', 'no', 'yes', 'no', 'yes', 'no']
}
df = pd.DataFrame(data)
df
# Out:
#   tam dram green
# 0   A  cor   yes
# 1   A  dis    no
# 2   B  cor   yes
# 3   B  dis    no
# 4   C  cor   yes
# 5   C  dis    no

# %%
import json

# Assuming you have a DataFrame 'df' with columns 'tam', 'dram', and 'green'
# df = pd.DataFrame(...)

# Function to create a nested dictionary with 'children'
def nest_children(row):
    return {
        'tam': row['tam'],
        'children': {
            'dram': row['dram'],
            'green': row['green']
        }
    }

grouped = df.groupby('tam').apply(lambda x: x[['dram', 'green']].to_dict('records')).reset_index(name='children')

# Convert each row of the grouped DataFrame to the desired dictionary structure
nested_data = grouped.apply(lambda row: {'tam': row['tam'], 'children': row['children']}, axis=1).tolist()

# Convert the list of dictionaries to a JSON string
json_data = json.dumps(nested_data, indent=4)

# %%
import json

# Assuming you have a DataFrame 'df' with columns 'tam', 'dram', and 'green'
# df = pd.DataFrame(...)

# Function to create a nested dictionary with 'children'
def nest_children(row):
    return {
        'tam': row['tam'],
        'tam': row['tam'],
        'tam': row['tam'],
        'tam': row['tam'],
        'tam': row['tam'],
        'tam': row['tam'],
        'tam': row['tam'],
        
        'children': {
            'dram': row['dram'],
            'green': row['green']
        }
    }

grouped = df.groupby('tam').apply(lambda x: x[['dram', 'green']].to_dict('records')).reset_index(name='children')

# Convert each row of the grouped DataFrame to the desired dictionary structure
nested_data = grouped.apply(lambda row: {'tam': row['tam'], 'children': row['children']}, axis=1).tolist()

# Convert the list of dictionaries to a JSON string
json_data = json.dumps(nested_data, indent=4)

# %%
json_data
# Out:
# '[\n    {\n        "tam": "A",\n        "children": [\n            {\n                "dram": "cor",\n                "green": "yes"\n            },\n            {\n                "dram": "dis",\n                "green": "no"\n            }\n        ]\n    },\n    {\n        "tam": "B",\n        "children": [\n            {\n                "dram": "cor",\n                "green": "yes"\n            },\n            {\n                "dram": "dis",\n                "green": "no"\n            }\n        ]\n    },\n    {\n        "tam": "C",\n        "children": [\n            {\n                "dram": "cor",\n                "green": "yes"\n            },\n            {\n                "dram": "dis",\n                "green": "no"\n            }\n        ]\n    }\n]'

# %%
json_data
# Out:
# '[\n    {\n        "tam": "A",\n        "children": {\n            "dram": "cor",\n            "green": "yes"\n        }\n    },\n    {\n        "tam": "A",\n        "children": {\n            "dram": "dis",\n            "green": "no"\n        }\n    },\n    {\n        "tam": "B",\n        "children": {\n            "dram": "cor",\n            "green": "yes"\n        }\n    },\n    {\n        "tam": "B",\n        "children": {\n            "dram": "dis",\n            "green": "no"\n        }\n    },\n    {\n        "tam": "C",\n        "children": {\n            "dram": "cor",\n            "green": "yes"\n        }\n    },\n    {\n        "tam": "C",\n        "children": {\n            "dram": "dis",\n            "green": "no"\n        }\n    }\n]'

# %%
nested_data
# Out:
# [{'tam': 'A', 'children': {'dram': 'cor', 'green': 'yes'}},
#  {'tam': 'A', 'children': {'dram': 'dis', 'green': 'no'}},
#  {'tam': 'B', 'children': {'dram': 'cor', 'green': 'yes'}},
#  {'tam': 'B', 'children': {'dram': 'dis', 'green': 'no'}},
#  {'tam': 'C', 'children': {'dram': 'cor', 'green': 'yes'}},
#  {'tam': 'C', 'children': {'dram': 'dis', 'green': 'no'}}]

# %%
grouped = df.groupby('tam').apply(lambda x: x[['dram', 'green']].to_dict('records')).reset_index(name='children')

# %%
from IPython.display import FileLink

# Save the JSON data to a file as before
filename = './daaata.json'  # Specify the path
with open(filename, 'w') as file:
    file.write(json_data)

# Create a download link for the file
FileLink('./daaata.json')
# Out:
# d:\OneDrive - PennO365\penn\5th\MUSA611\dashboard\daaata.json
